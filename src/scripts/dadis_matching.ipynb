# %%
import csv
import json
import os
from typing import IO, TextIO

import pandas as pd

from dadis_client.client import DadisClient

# %%
API_KEY = os.environ["DADIS_API_KEY"]

# %%
client = DadisClient(api_key=API_KEY, prod=True)

# %%
def full_matching_workflow(
    input_filename: str,
    output_filename: str,
    dadis_api_key: str) -> pd.DataFrame:
    """
    Perform the full matching workflow:

    - Read VBO data from input_filename
    - Match to DADIS to get dadis_transboundary_id
    - Save to a new TSV file at output_filename
    """
    client = DadisClient(api_key=dadis_api_key)
    vbo_data = read_vbo_data(input_filename)
    matched_breeds = match_vbo_breeds(vbo_data=vbo_data, client=client)

    print(f"Writing output file to {output_filename}:")
    output_file = create_output_tsv(input_filename=input_filename, output_filename=output_filename, extra_cols=["dadis_transboundary_id"])
    matched_breeds.to_csv(output_file, sep="\t", index=False, header=False)
    output_file.close()
    print("Output written.")
    return matched_breeds
    

def read_vbo_data(filename: str) -> pd.DataFrame:
    df = pd.read_table(filename, skiprows=[1]).convert_dtypes()
    print("Dropping duplicate entry for: VBO:0000991 - Icelandic Horse/Iceland Pony")
    dup_entry = (df["VBO id"] == "VBO:0000991") & (df["term label"].isna())
    return df.loc[~ dup_entry, :]


def get_dadis_species(client: DadisClient) -> pd.DataFrame:
    resp = client.get_all_species()
    all_species = []
    for s in resp.response:
        species = {"dadis_species_id": s.id, "species_name": s.name["en"]}
        all_species.append(species)
    return pd.DataFrame.from_records(all_species)


def get_canonical_dadis_transboundary(client: DadisClient) -> pd.DataFrame:
    """
    DADIS has a canonical name for each transboundary breed, fetch these
    and return them as a dataframe
    """
    resp = client.get_all_transboundary_names()
    df = (
        pd.DataFrame.from_records([b.model_dump() for b in resp.response])
        .rename(columns={"speciesId": "dadis_species_id"})
    )
    species_df = get_dadis_species(client)
    df = df.merge(species_df, how="left", on="dadis_species_id")
    df = df.rename(columns={"id": "dadis_transboundary_id", "name": "dadis_breed_name"})
    return df

def get_all_dadis_transboundary(client: DadisClient) -> pd.DataFrame:
    """
    Get all names for DADIS transboundary breeds, some VBO entries
    may use non-canonical names
    """
    resp = client.get_all_transboundary_breeds()
    df = (
        pd.DataFrame.from_records([b.model_dump() for b in resp.response])
        .rename(columns={
            "speciesId": "dadis_species_id", 
            "name": "dadis_breed_name", 
            "transboundaryId": "dadis_transboundary_id",
            "id": "dadis_breed_id",
            "iso3": "dadis_iso3_code",
        })
        .drop_duplicates(subset=["dadis_species_id", "dadis_breed_name", "dadis_transboundary_id"])
    )
    species_df = get_dadis_species(client)
    result = (
        df
        .merge(species_df, how="left", on="dadis_species_id")
        .sort_values(["dadis_transboundary_id", "dadis_breed_name"])
    )
    return result


def get_simple_matches(vbo_data: pd.DataFrame, client: DadisClient) -> pd.DataFrame:
    """
    Match VBO entries to DADIS transboundary breeds based on their
    canonical names. Return a dataframe containing the matches
    """
    dadis_canonical = get_canonical_dadis_transboundary(client=client)
    simple_matches = (
        vbo_data[["VBO id", "term label", "DADIS_name", "DADIS_species_name"]].merge(
            dadis_canonical,
            how="left",
            left_on=["DADIS_name", "DADIS_species_name"],
            right_on=["dadis_breed_name", "species_name"],
            sort=False,
        )
        .drop(columns=["dadis_breed_name", "species_name"])
        .convert_dtypes()
    )
    return simple_matches


def get_extra_matches(vbo_data: pd.DataFrame, client: DadisClient) -> pd.DataFrame:
    dadis_all = get_all_dadis_transboundary(client=client)
    extra_matches = (
        vbo_data[["VBO id", "term label", "DADIS_name", "DADIS_species_name"]].merge(
            dadis_all,
            how="left",
            left_on=["DADIS_name", "DADIS_species_name"],
            right_on=["dadis_breed_name", "species_name"],
            indicator=True,
            # Need to ensure we use sort=False so order stays consistent with original
            sort=False,
        )
        .drop(columns=["dadis_breed_name", "species_name"])
        .convert_dtypes()
        .drop_duplicates(subset=["VBO id", "dadis_transboundary_id"])
    )
    counts = extra_matches["VBO id"].value_counts()
    duplicates = counts.loc[counts >=2 ].index.tolist()
    multiple_matches = extra_matches.loc[extra_matches["VBO id"].isin(duplicates), :]
    print("The following entries matched against multiple DADIS entries - will not be updated")
    print(multiple_matches["VBO id"])
    extra_matches = extra_matches.loc[~ extra_matches["VBO id"].isin(duplicates), :]
    return extra_matches


def match_vbo_breeds(vbo_data: pd.DataFrame, client: DadisClient) -> pd.DataFrame:
    """
    Match VBO entries to DADIS, based on both canonical name (preferred) or
    other transboundary name.

    Return a modified copy of vbo_data, with the 'dadis_transboundary_id' added
    """
    print("Matching to canonical DADIS names")
    simple_matches = get_simple_matches(vbo_data, client)
    print("Matching to other DADIS names")
    extra_matches = get_extra_matches(vbo_data, client)
    all_matches = simple_matches.merge(
        extra_matches[["VBO id", "dadis_transboundary_id", "dadis_species_id"]],
        how="left",
        on="VBO id",
        suffixes=(None, "_extra"),
        sort=False
    ).convert_dtypes()
    # Fill in simple matches with extra matches, where no simple match was found
    simple_ids = all_matches["dadis_transboundary_id"]
    extra_ids = all_matches["dadis_transboundary_id_extra"]
    all_matches["dadis_transboundary_id"] = simple_ids.where(~ simple_ids.isna(), extra_ids)

    n_total = all_matches.shape[0]
    n_matched = all_matches["dadis_transboundary_id"].notna().sum()
    print(f"{n_matched} / {n_total} VBO entries matched with DADIS")
    
    return vbo_data.merge(
        all_matches[["VBO id", "dadis_transboundary_id"]],
        on="VBO id",
        how="left",
        sort=False
    )


def create_output_tsv(input_filename: str, output_filename: str, extra_cols: list[str] = None) -> TextIO:
    """
    Copy the 2 header lines from the input file to the output file. Return
    a file object for the output file, so pandas can write the rest of the file
    """
    file_out = open(output_filename, "w")
    csv_out = csv.writer(file_out, dialect="excel-tab")
    with open(input_filename) as file_in:
        csv_in = csv.reader(file_in, dialect="excel-tab")
        for index, line in enumerate(range(2)):
            header = next(csv_in)
            if extra_cols is not None:
                if index == 0:
                    header += extra_cols
                if index == 1:
                    header += ['' for i in range(len(extra_cols))]
            csv_out.writerow(header)
    return file_out

# %% [markdown]
# # Test full updating process

# %%
result = full_matching_workflow(input_filename="data/dadistransbound.tsv", output_filename="example_transboundary_output.tsv", dadis_api_key=API_KEY)
# Out:
# Dropping duplicate entry for: VBO:0000991 - Icelandic Horse/Iceland Pony
# Matching to canonical DADIS names
# Matching to other DADIS names
# The following entries matched against multiple DADIS entries - will not be updated
# 19      VBO:0000056
# 20      VBO:0000056
# 67      VBO:0000104
# 68      VBO:0000104
# 144     VBO:0000184
# 145     VBO:0000184
# 168     VBO:0000207
# 169     VBO:0000207
# 177     VBO:0000215
# 178     VBO:0000215
# 227     VBO:0000265
# 228     VBO:0000265
# 235     VBO:0000272
# 236     VBO:0000272
# 279     VBO:0000315
# 280     VBO:0000315
# 286     VBO:0000321
# 287     VBO:0000321
# 355     VBO:0000389
# 356     VBO:0000389
# 389     VBO:0000422
# 390     VBO:0000422
# 414     VBO:0000446
# 415     VBO:0000446
# 614     VBO:0000645
# 615     VBO:0000645
# 677     VBO:0000717
# 678     VBO:0000717
# 711     VBO:0000751
# 712     VBO:0000751
# 911     VBO:0000951
# 912     VBO:0000951
# 1107    VBO:0001146
# 1108    VBO:0001146
# 1123    VBO:0001161
# 1124    VBO:0001161
# 1212    VBO:0001249
# 1213    VBO:0001249
# 1217    VBO:0001253
# 1218    VBO:0001253
# 1423    VBO:0001461
# 1424    VBO:0001461
# 1504    VBO:0001541
# 1505    VBO:0001541
# Name: VBO id, dtype: string
# 1052 / 1673 VBO entries matched with DADIS
# Writing output file to example_transboundary_output.tsv:
# Output written.

# %%
result.head()
# Out:
#         VBO id                       term label  \
# 0  VBO:0000012         Dromedary Bactrian Camel
# 1  VBO:0000038                  Alpaca (Alpaca)
# 2  VBO:0000039                 Huacaya (Alpaca)
# 3  VBO:0000040                    Suri (Alpaca)
# 4  VBO:0000041  American Bison (American Bison)
#
#   breed name to be used for label species to be used for label  \
# 0                            <NA>                         <NA>
# 1                          Alpaca                       Alpaca
# 2                         Huacaya                       Alpaca
# 3                            Suri                       Alpaca
# 4                  American Bison               American Bison
#
#   internal term merge indicator vboid into vboid  \
# 0                                           <NA>
# 1                                           <NA>
# 2                                           <NA>
# 3                                           <NA>
# 4                                           <NA>
#
#   internal date and issue separated by pipe YYMMDD-issue  \
# 0                                               <NA>
# 1                                               <NA>
# 2                                               <NA>
# 3                                               <NA>
# 4                                               <NA>
#
#   GH issue NOT merge obsolete        parent ID          source for parents  \
# 0                        <NA>   NCBITaxon:9836                        <NA>
# 1                        <NA>  NCBITaxon:30538  https://www.fao.org/dad-is
# 2                        <NA>  NCBITaxon:30538  https://www.fao.org/dad-is
# 3                        <NA>  NCBITaxon:30538  https://www.fao.org/dad-is
# 4                        <NA>   NCBITaxon:9901  https://www.fao.org/dad-is
#
#                                 source for parents.1  ...  replacement label  \
# 0  DOI:10.1016/j.jasrep.2021.103038|PMID:31969478...  ...               <NA>
# 1                                               <NA>  ...               <NA>
# 2                                               <NA>  ...               <NA>
# 3                                               <NA>  ...               <NA>
# 4                                               <NA>  ...               <NA>
#
#    comment.1  GH issue obsolescence reason curator note      DADIS_name  \
# 0       <NA>      <NA>                <NA>         <NA>            <NA>
# 1       <NA>      <NA>                <NA>         <NA>          Alpaca
# 2       <NA>      <NA>                <NA>         <NA>         Huacaya
# 3       <NA>      <NA>                <NA>         <NA>            Suri
# 4       <NA>      <NA>                <NA>         <NA>  American Bison
#
#    DADIS_species_name DADIS_country DADIS_ISO3_code  dadis_transboundary_id
# 0                <NA>          <NA>            <NA>                    <NA>
# 1              Alpaca          <NA>            <NA>                    <NA>
# 2              Alpaca          <NA>            <NA>                     1-1
# 3              Alpaca          <NA>            <NA>                     1-2
# 4      American Bison          <NA>            <NA>                     2-1
#
# [5 rows x 90 columns]

# %% [markdown]
# # Step-by-step process: for debugging
#
# Note: may not be fully up to date with the process above.

# %%
dadis_species = get_dadis_species(client)
dadis_species.head()
# Out:
#    dadis_species_id    species_name
# 0                 1          Alpaca
# 1                 2  American Bison
# 2                 3             Ass
# 3                 4  Bactrian camel
# 4                 5         Buffalo

# %%
dadis_canonical = get_canonical_dadis_transboundary(client=client)
dadis_canonical.head()
# Out:
#   dadis_transboundary_id  dadis_species_id dadis_breed_name    species_name
# 0                    1-1                 1          Huacaya          Alpaca
# 1                    1-2                 1             Suri          Alpaca
# 2                    2-1                 2   American Bison  American Bison
# 3                    3-1                 3      Asino Sardo             Ass
# 4                    3-2                 3    Balkan Donkey             Ass

# %%
dadis_all = get_all_dadis_transboundary(client=client)
dadis_all.head()
# Out:
#                             dadis_breed_id dadis_breed_name dadis_iso3_code  \
# 147   da0f5e4b-2dc4-4119-bb9a-6d87d88b2a3c          Huacaya             AUS
# 148   32354ff8-1f74-4e90-abb5-657753427508             Suri             AUS
# 617   56378f94-0804-411b-a7bd-a9b0a43bf187             Sury             BOL
# 1091  ba06f2a8-caca-4dce-8c22-8599b349b85e             Test             DEU
# 242   0c273dfe-f832-431b-938a-b9235a6dbffc           Chital             AUS
#
#       dadis_species_id dadis_transboundary_id      updatedAt species_name
# 147                  1                    1-1  1652172491000       Alpaca
# 148                  1                    1-2  1652172491000       Alpaca
# 617                  1                    1-2  1665583332000       Alpaca
# 1091                 1                    1-2  1678781404000       Alpaca
# 242                 11                   11-1  1652172493000         Deer

# %%
dadis_all.dtypes
# Out:
# dadis_breed_id            object
# dadis_breed_name          object
# dadis_iso3_code           object
# dadis_species_id           int64
# dadis_transboundary_id    object
# updatedAt                  int64
# species_name              object
# dtype: object

# %% [markdown]
# ## VBO transboundary data

# %%
VBO_TRANSBOUNDARY_FILENAME = "data/dadistransbound.tsv"

# %%
vbo_transboundary = pd.read_table(VBO_TRANSBOUNDARY_FILENAME, skiprows=[1]).convert_dtypes()
# Drop problematic entry: VBO:0000991 - Icelandic Horse/Iceland Pony
dup_entry = (vbo_transboundary["VBO id"] == "VBO:0000991") & (vbo_transboundary["term label"].isna())
vbo_transboundary = vbo_transboundary.loc[~ dup_entry, :]
vbo_transboundary.head()
# Out:
#         VBO id                       term label  \
# 0  VBO:0000012         Dromedary Bactrian Camel
# 1  VBO:0000038                  Alpaca (Alpaca)
# 2  VBO:0000039                 Huacaya (Alpaca)
# 3  VBO:0000040                    Suri (Alpaca)
# 4  VBO:0000041  American Bison (American Bison)
#
#   breed name to be used for label species to be used for label  \
# 0                            <NA>                         <NA>
# 1                          Alpaca                       Alpaca
# 2                         Huacaya                       Alpaca
# 3                            Suri                       Alpaca
# 4                  American Bison               American Bison
#
#   internal term merge indicator vboid into vboid  \
# 0                                           <NA>
# 1                                           <NA>
# 2                                           <NA>
# 3                                           <NA>
# 4                                           <NA>
#
#   internal date and issue separated by pipe YYMMDD-issue  \
# 0                                               <NA>
# 1                                               <NA>
# 2                                               <NA>
# 3                                               <NA>
# 4                                               <NA>
#
#   GH issue NOT merge obsolete        parent ID          source for parents  \
# 0                        <NA>   NCBITaxon:9836                        <NA>
# 1                        <NA>  NCBITaxon:30538  https://www.fao.org/dad-is
# 2                        <NA>  NCBITaxon:30538  https://www.fao.org/dad-is
# 3                        <NA>  NCBITaxon:30538  https://www.fao.org/dad-is
# 4                        <NA>   NCBITaxon:9901  https://www.fao.org/dad-is
#
#                                 source for parents.1  ...  replacement term  \
# 0  DOI:10.1016/j.jasrep.2021.103038|PMID:31969478...  ...              <NA>
# 1                                               <NA>  ...              <NA>
# 2                                               <NA>  ...              <NA>
# 3                                               <NA>  ...              <NA>
# 4                                               <NA>  ...              <NA>
#
#    replacement label  comment.1 GH issue obsolescence reason curator note  \
# 0               <NA>       <NA>     <NA>                <NA>         <NA>
# 1               <NA>       <NA>     <NA>                <NA>         <NA>
# 2               <NA>       <NA>     <NA>                <NA>         <NA>
# 3               <NA>       <NA>     <NA>                <NA>         <NA>
# 4               <NA>       <NA>     <NA>                <NA>         <NA>
#
#        DADIS_name DADIS_species_name DADIS_country  DADIS_ISO3_code
# 0            <NA>               <NA>          <NA>             <NA>
# 1          Alpaca             Alpaca          <NA>             <NA>
# 2         Huacaya             Alpaca          <NA>             <NA>
# 3            Suri             Alpaca          <NA>             <NA>
# 4  American Bison     American Bison          <NA>             <NA>
#
# [5 rows x 89 columns]

# %%
vbo_transboundary.loc[vbo_transboundary["VBO id"] == "VBO:0000991", :]
# Out:
#           VBO id               term label breed name to be used for label  \
# 936  VBO:0000991  Icelandic Horse (Horse)                 Icelandic Horse
#
#     species to be used for label  \
# 936                        Horse
#
#     internal term merge indicator vboid into vboid  \
# 936                   VBO:0000990 into VBO:0000991
#
#     internal date and issue separated by pipe YYMMDD-issue  \
# 936                                          230207-75
#
#     GH issue NOT merge obsolete       parent ID          source for parents  \
# 936                        <NA>  NCBITaxon:9796  https://www.fao.org/dad-is
#
#     source for parents.1  ...  replacement term  replacement label  comment.1  \
# 936                 <NA>  ...              <NA>               <NA>       <NA>
#
#     GH issue obsolescence reason curator note       DADIS_name  \
# 936     <NA>                <NA>         <NA>  Icelandic Horse
#
#     DADIS_species_name DADIS_country  DADIS_ISO3_code
# 936              Horse          <NA>             <NA>
#
# [1 rows x 89 columns]

# %%
vbo_transboundary.shape
# Out:
# (1673, 89)

# %%
vbo_matched = match_vbo_breeds(vbo_data=vbo_transboundary, client=client)
print(vbo_matched.shape)
vbo_matched.head()
# Out:
# Matching to canonical DADIS names
# Matching to other DADIS names
# The following entries matched against multiple DADIS entries - will not be updated
# 19      VBO:0000056
# 20      VBO:0000056
# 67      VBO:0000104
# 68      VBO:0000104
# 144     VBO:0000184
# 145     VBO:0000184
# 168     VBO:0000207
# 169     VBO:0000207
# 177     VBO:0000215
# 178     VBO:0000215
# 227     VBO:0000265
# 228     VBO:0000265
# 235     VBO:0000272
# 236     VBO:0000272
# 279     VBO:0000315
# 280     VBO:0000315
# 286     VBO:0000321
# 287     VBO:0000321
# 355     VBO:0000389
# 356     VBO:0000389
# 389     VBO:0000422
# 390     VBO:0000422
# 414     VBO:0000446
# 415     VBO:0000446
# 614     VBO:0000645
# 615     VBO:0000645
# 677     VBO:0000717
# 678     VBO:0000717
# 711     VBO:0000751
# 712     VBO:0000751
# 911     VBO:0000951
# 912     VBO:0000951
# 1107    VBO:0001146
# 1108    VBO:0001146
# 1123    VBO:0001161
# 1124    VBO:0001161
# 1212    VBO:0001249
# 1213    VBO:0001249
# 1217    VBO:0001253
# 1218    VBO:0001253
# 1423    VBO:0001461
# 1424    VBO:0001461
# 1504    VBO:0001541
# 1505    VBO:0001541
# Name: VBO id, dtype: string
# 1052 / 1673 VBO entries matched with DADIS
# (1673, 90)
#         VBO id                       term label  \
# 0  VBO:0000012         Dromedary Bactrian Camel
# 1  VBO:0000038                  Alpaca (Alpaca)
# 2  VBO:0000039                 Huacaya (Alpaca)
# 3  VBO:0000040                    Suri (Alpaca)
# 4  VBO:0000041  American Bison (American Bison)
#
#   breed name to be used for label species to be used for label  \
# 0                            <NA>                         <NA>
# 1                          Alpaca                       Alpaca
# 2                         Huacaya                       Alpaca
# 3                            Suri                       Alpaca
# 4                  American Bison               American Bison
#
#   internal term merge indicator vboid into vboid  \
# 0                                           <NA>
# 1                                           <NA>
# 2                                           <NA>
# 3                                           <NA>
# 4                                           <NA>
#
#   internal date and issue separated by pipe YYMMDD-issue  \
# 0                                               <NA>
# 1                                               <NA>
# 2                                               <NA>
# 3                                               <NA>
# 4                                               <NA>
#
#   GH issue NOT merge obsolete        parent ID          source for parents  \
# 0                        <NA>   NCBITaxon:9836                        <NA>
# 1                        <NA>  NCBITaxon:30538  https://www.fao.org/dad-is
# 2                        <NA>  NCBITaxon:30538  https://www.fao.org/dad-is
# 3                        <NA>  NCBITaxon:30538  https://www.fao.org/dad-is
# 4                        <NA>   NCBITaxon:9901  https://www.fao.org/dad-is
#
#                                 source for parents.1  ...  replacement label  \
# 0  DOI:10.1016/j.jasrep.2021.103038|PMID:31969478...  ...               <NA>
# 1                                               <NA>  ...               <NA>
# 2                                               <NA>  ...               <NA>
# 3                                               <NA>  ...               <NA>
# 4                                               <NA>  ...               <NA>
#
#    comment.1  GH issue obsolescence reason curator note      DADIS_name  \
# 0       <NA>      <NA>                <NA>         <NA>            <NA>
# 1       <NA>      <NA>                <NA>         <NA>          Alpaca
# 2       <NA>      <NA>                <NA>         <NA>         Huacaya
# 3       <NA>      <NA>                <NA>         <NA>            Suri
# 4       <NA>      <NA>                <NA>         <NA>  American Bison
#
#    DADIS_species_name DADIS_country DADIS_ISO3_code  dadis_transboundary_id
# 0                <NA>          <NA>            <NA>                    <NA>
# 1              Alpaca          <NA>            <NA>                    <NA>
# 2              Alpaca          <NA>            <NA>                     1-1
# 3              Alpaca          <NA>            <NA>                     1-2
# 4      American Bison          <NA>            <NA>                     2-1
#
# [5 rows x 90 columns]

# %%
vbo_matched["VBO id"].value_counts()
# Out:
# VBO id
# VBO:0000012    1
# VBO:0000142    1
# VBO:0000040    1
# VBO:0000041    1
# VBO:0000042    1
#               ..
# VBO:0016849    1
# VBO:0016850    1
# VBO:0016851    1
# VBO:0016852    1
# VBO:0016853    1
# Name: count, Length: 1673, dtype: Int64

# %% [markdown]
# ### Test TSV output with double header

# %%
# Create file with just the 2 header lines
output_tsv = create_output_tsv(input_filename=VBO_TRANSBOUNDARY_FILENAME, output_filename="output_test.tsv", extra_cols=["dadis_transboundary_id"])
# Write the DF from pandas, not including the header
vbo_transboundary.to_csv(output_tsv, sep="\t", index=False, header=False)

# %% [markdown]
# ### Simple matches: direct match to canonical DADIS name

# %%
simple_matches = vbo_transboundary[["VBO id", "term label", "DADIS_name", "DADIS_species_name"]].merge(
    dadis_canonical,
    how="left",
    left_on=["DADIS_name", "DADIS_species_name"],
    right_on=["dadis_breed_name", "species_name"],
    indicator=True,
    # Need to ensure we use sort=False so order stays consistent with original
    sort=False,
).drop(columns=["dadis_breed_name", "species_name"]).convert_dtypes()
simple_matches.head()
# Out:
#         VBO id                       term label      DADIS_name  \
# 0  VBO:0000012         Dromedary Bactrian Camel            <NA>
# 1  VBO:0000038                  Alpaca (Alpaca)          Alpaca
# 2  VBO:0000039                 Huacaya (Alpaca)         Huacaya
# 3  VBO:0000040                    Suri (Alpaca)            Suri
# 4  VBO:0000041  American Bison (American Bison)  American Bison
#
#   DADIS_species_name dadis_transboundary_id  dadis_species_id     _merge
# 0               <NA>                   <NA>              <NA>  left_only
# 1             Alpaca                   <NA>              <NA>  left_only
# 2             Alpaca                    1-1                 1       both
# 3             Alpaca                    1-2                 1       both
# 4     American Bison                    2-1                 2       both

# %%
simple_matches["_merge"].value_counts()
# Out:
# _merge
# both          1009
# left_only      664
# right_only       0
# Name: count, dtype: int64

# %%
simple_matches["VBO id"].value_counts()
# Out:
# VBO id
# VBO:0000012    1
# VBO:0000142    1
# VBO:0000040    1
# VBO:0000041    1
# VBO:0000042    1
#               ..
# VBO:0016849    1
# VBO:0016850    1
# VBO:0016851    1
# VBO:0016852    1
# VBO:0016853    1
# Name: count, Length: 1673, dtype: Int64

# %%
simple_matches.shape
# Out:
# (1673, 7)

# %% [markdown]
# ## Additional matching: match to non-canonical DADIS names

# %%
extra_matches = vbo_transboundary[["VBO id", "term label", "DADIS_name", "DADIS_species_name"]].merge(
    dadis_all,
    how="left",
    left_on=["DADIS_name", "DADIS_species_name"],
    right_on=["dadis_breed_name", "species_name"],
    indicator=True,
    # Need to ensure we use sort=False so order stays consistent with original
    sort=False,
).drop(columns=["dadis_breed_name", "species_name"])
extra_matches.head()
# Out:
#         VBO id                       term label      DADIS_name  \
# 0  VBO:0000012         Dromedary Bactrian Camel            <NA>
# 1  VBO:0000038                  Alpaca (Alpaca)          Alpaca
# 2  VBO:0000039                 Huacaya (Alpaca)         Huacaya
# 3  VBO:0000040                    Suri (Alpaca)            Suri
# 4  VBO:0000041  American Bison (American Bison)  American Bison
#
#   DADIS_species_name                        dadis_breed_id dadis_iso3_code  \
# 0               <NA>                                   NaN             NaN
# 1             Alpaca                                   NaN             NaN
# 2             Alpaca  da0f5e4b-2dc4-4119-bb9a-6d87d88b2a3c             AUS
# 3             Alpaca  32354ff8-1f74-4e90-abb5-657753427508             AUS
# 4     American Bison                                   NaN             NaN
#
#    dadis_species_id dadis_transboundary_id     updatedAt     _merge
# 0               NaN                    NaN           NaN  left_only
# 1               NaN                    NaN           NaN  left_only
# 2               1.0                    1-1  1.652172e+12       both
# 3               1.0                    1-2  1.652172e+12       both
# 4               NaN                    NaN           NaN  left_only

# %%
dup_matches = extra_matches["VBO id"].value_counts().pipe(lambda x: x.loc[x >= 2]).index.tolist()
dup_matches
# Out:
# ['VBO:0001253',
#  'VBO:0000422',
#  'VBO:0001461',
#  'VBO:0000321',
#  'VBO:0000272',
#  'VBO:0000207',
#  'VBO:0000104',
#  'VBO:0000265',
#  'VBO:0001249',
#  'VBO:0000951',
#  'VBO:0000184',
#  'VBO:0000315',
#  'VBO:0000215',
#  'VBO:0000056',
#  'VBO:0000751',
#  'VBO:0000645',
#  'VBO:0001146',
#  'VBO:0001541',
#  'VBO:0000446',
#  'VBO:0001161',
#  'VBO:0000389',
#  'VBO:0000717']

# %%
extra_matches.loc[extra_matches["VBO id"].isin(dup_matches), :].drop_duplicates(subset=["VBO id", "dadis_transboundary_id"])
# Out:
#            VBO id                         term label  \
# 19    VBO:0000056       Native of North Africa (Ass)
# 20    VBO:0000056       Native of North Africa (Ass)
# 67    VBO:0000104                     Angus (Cattle)
# 68    VBO:0000104                     Angus (Cattle)
# 144   VBO:0000184                   Dahomey (Cattle)
# 145   VBO:0000184                   Dahomey (Cattle)
# 168   VBO:0000207                  Galloway (Cattle)
# 169   VBO:0000207                  Galloway (Cattle)
# 177   VBO:0000215                       Gir (Cattle)
# 178   VBO:0000215                       Gir (Cattle)
# 227   VBO:0000265                      Kuri (Cattle)
# 228   VBO:0000265                      Kuri (Cattle)
# 235   VBO:0000272                  Limangus (Cattle)
# 236   VBO:0000272                  Limangus (Cattle)
# 279   VBO:0000315                    N'dama (Cattle)
# 280   VBO:0000315                    N'dama (Cattle)
# 286   VBO:0000321                     Nkone (Cattle)
# 287   VBO:0000321                     Nkone (Cattle)
# 355   VBO:0000389                    Sussex (Cattle)
# 356   VBO:0000389                    Sussex (Cattle)
# 389   VBO:0000422                     Wagyu (Cattle)
# 390   VBO:0000422                     Wagyu (Cattle)
# 414   VBO:0000446                    Aseel (Chicken)
# 415   VBO:0000446                    Aseel (Chicken)
# 614   VBO:0000645            White Cornish (Chicken)
# 615   VBO:0000645            White Cornish (Chicken)
# 677   VBO:0000717                      Alpine (Goat)
# 678   VBO:0000717                      Alpine (Goat)
# 711   VBO:0000751                     Criollo (Goat)
# 712   VBO:0000751                     Criollo (Goat)
# 911   VBO:0000951                    Dongola (Horse)
# 912   VBO:0000951                    Dongola (Horse)
# 1107  VBO:0001146                    Hampshire (Pig)
# 1108  VBO:0001146                    Hampshire (Pig)
# 1123  VBO:0001161                     Landrace (Pig)
# 1124  VBO:0001161                     Landrace (Pig)
# 1212  VBO:0001249             Flemish Giant (Rabbit)
# 1213  VBO:0001249             Flemish Giant (Rabbit)
# 1217  VBO:0001253        Géant des Flandres (Rabbit)
# 1218  VBO:0001253        Géant des Flandres (Rabbit)
# 1423  VBO:0001461                    Karakul (Sheep)
# 1424  VBO:0001461                    Karakul (Sheep)
# 1504  VBO:0001541  Ostfriesisches Milchschaf (Sheep)
# 1505  VBO:0001541  Ostfriesisches Milchschaf (Sheep)
#
#                      DADIS_name DADIS_species_name  \
# 19       Native of North Africa                Ass
# 20       Native of North Africa                Ass
# 67                        Angus             Cattle
# 68                        Angus             Cattle
# 144                     Dahomey             Cattle
# 145                     Dahomey             Cattle
# 168                    Galloway             Cattle
# 169                    Galloway             Cattle
# 177                         Gir             Cattle
# 178                         Gir             Cattle
# 227                        Kuri             Cattle
# 228                        Kuri             Cattle
# 235                    Limangus             Cattle
# 236                    Limangus             Cattle
# 279                      N'dama             Cattle
# 280                      N'dama             Cattle
# 286                       Nkone             Cattle
# 287                       Nkone             Cattle
# 355                      Sussex             Cattle
# 356                      Sussex             Cattle
# 389                       Wagyu             Cattle
# 390                       Wagyu             Cattle
# 414                       Aseel            Chicken
# 415                       Aseel            Chicken
# 614               White Cornish            Chicken
# 615               White Cornish            Chicken
# 677                      Alpine               Goat
# 678                      Alpine               Goat
# 711                     Criollo               Goat
# 712                     Criollo               Goat
# 911                     Dongola              Horse
# 912                     Dongola              Horse
# 1107                  Hampshire                Pig
# 1108                  Hampshire                Pig
# 1123                   Landrace                Pig
# 1124                   Landrace                Pig
# 1212              Flemish Giant             Rabbit
# 1213              Flemish Giant             Rabbit
# 1217         Géant des Flandres             Rabbit
# 1218         Géant des Flandres             Rabbit
# 1423                    Karakul              Sheep
# 1424                    Karakul              Sheep
# 1504  Ostfriesisches Milchschaf              Sheep
# 1505  Ostfriesisches Milchschaf              Sheep
#
#                             dadis_breed_id dadis_iso3_code  dadis_species_id  \
# 19    80cb2410-d98c-4d27-8caf-4d7b3277c5fe             MLI               3.0
# 20    a352977b-46e3-48b1-a451-a7763eef50c2             SEN               3.0
# 67    3b6861eb-4ef6-4dea-9071-29b0c204f308             AUS               7.0
# 68    e13ccc87-28ba-4197-904e-0506824c624c             HRV               7.0
# 144   fddd374d-e930-4a71-bae0-6ecfc9c1d16a             COD               7.0
# 145   fcff27c9-256a-44ea-9b75-cd2b2dc5719c             NLD               7.0
# 168   35f26b3a-689c-435f-b50a-0cba8018c0f0             NOR               7.0
# 169   b192cee5-00da-4585-ba6c-1921a6cf2071             AUS               7.0
# 177   c5846f95-7c48-4a9b-ac3c-18b647123b69             BRA               7.0
# 178   02f31ff8-1076-4451-876a-da86974a8999             AUS               7.0
# 227   c34268d2-4ef8-4d76-bd1a-621609bb7e8f             CMR               7.0
# 228   74cbc1b2-f4eb-47c8-8d90-3fd7b30cdf02             NER               7.0
# 235   f1a46380-9530-4e11-bab4-1fb77c4d90ee             URY               7.0
# 236   0a998f2c-8d6d-4c05-93ae-795e0e7564ed             ARG               7.0
# 279   c0208ad6-d731-4e08-8240-d8baeadaf1bb             BEN               7.0
# 280   5767c44d-9742-4707-b332-aa39b29d8959             GAB               7.0
# 286   47a99856-9137-44b8-af53-ff6451e99af9             ZWE               7.0
# 287   1dea54c9-e42b-4feb-8c79-6a2fda179a3d             ZAF               7.0
# 355   e9b99ea3-b5b9-4b64-80a4-188d06243cc7             ZAF               7.0
# 356   cd25e6b2-f7fa-4e2c-9d92-6cf7e0959ea0             AUS               7.0
# 389   d5ef4be0-41e0-415b-b3b5-07bdc61eefb7             AUS               7.0
# 390   9a5be0af-a40a-4884-8f91-7cc06b7dd9f6             BEL               7.0
# 414   3bd7e9f3-1f08-4449-a4f5-574522b5e3d6             BGD               8.0
# 415   78e84f51-e5c5-492a-8139-0c59855c7d69             BOL               8.0
# 614   485ac57a-9500-43b4-96cc-83afe35dd96e             JPN               8.0
# 615   3ce476fc-c33a-414d-9837-372d95eecd20             KOR               8.0
# 677   e486e58f-4e60-45e3-a61e-4484b99a0a47             ALB              19.0
# 678   0fbeef1e-551e-4a1b-97d8-7e9fbe5d8413             FRA              19.0
# 711   9f1cd072-15a9-4c73-947a-7d3d067aaf2c             TTO              19.0
# 712   0eeaee0d-9d83-414b-9d8c-2007f5a59a5a             BOL              19.0
# 911   3f97ecd0-a95e-4f2a-818e-d90c35269573             TCD              24.0
# 912   ea6500d4-8075-470d-81e6-e452514c13a5             ERI              24.0
# 1107  e3c2006d-a7c0-42ae-82cc-9edae4eab8f1             USA              33.0
# 1108  02c63356-037b-43b2-9438-10bcea8d2183             ATG              33.0
# 1123  69628978-ea83-4dcc-801d-c2c12b32f4d9             FRA              33.0
# 1124  44e6e3a3-7d0e-4de2-8feb-b6aaac727f72             AGO              33.0
# 1212  193ba9a1-3c4b-4d95-aef2-4680522a335b             BGR              37.0
# 1213  6243aea6-122d-4637-88ab-ca6e1e1adf4f             DMA              37.0
# 1217  3606efa6-657c-48d7-8dc4-e51527090591             FRA              37.0
# 1218  9002e4e7-297d-41a7-af17-bdf7df9cea6a             TGO              37.0
# 1423  85a82103-3157-41d5-acc5-a3826eb9368b             AFG              38.0
# 1424  10992f76-1fa4-4f7a-98f1-f0c794f044a1             USA              38.0
# 1504  b7edb362-f078-4ba2-a7cb-727e70ba5628             DEU              38.0
# 1505  d25c3cf2-a38c-4426-a489-4f799821847d             AUT              38.0
#
#      dadis_transboundary_id     updatedAt _merge
# 19                     3-12  1.639731e+12   both
# 20                     3-17  1.639732e+12   both
# 67                      7-2  1.666926e+12   both
# 68                      7-7  1.652173e+12   both
# 144                   7-123  1.652173e+12   both
# 145                    7-69  1.675160e+12   both
# 168                    7-40  1.687858e+12   both
# 169                    7-85  1.666928e+12   both
# 177                    7-70  1.668051e+12   both
# 178                    7-89  1.667361e+12   both
# 227                   7-122  1.639729e+12   both
# 228                   7-217  1.643203e+12   both
# 235                   7-127  1.643751e+12   both
# 236                   7-128  1.639728e+12   both
# 279                   7-153  1.665582e+12   both
# 280                     7-8  1.665600e+12   both
# 286                   7-156  1.697501e+12   both
# 287                   7-157  1.639733e+12   both
# 355                   7-168  1.665641e+12   both
# 356                   7-199  1.666930e+12   both
# 389                   7-109  1.666930e+12   both
# 390                   7-213  1.674469e+12   both
# 414                     8-8  1.639728e+12   both
# 415                    8-93  1.652173e+12   both
# 614                   8-169  1.639730e+12   both
# 615                    8-77  1.652173e+12   both
# 677                    19-2  1.639728e+12   both
# 678                   19-28  1.689923e+12   both
# 711                   19-22  1.665635e+12   both
# 712                   19-23  1.639729e+12   both
# 911                  24-139  1.639732e+12   both
# 912                   24-47  1.639729e+12   both
# 1107                   33-2  1.646403e+12   both
# 1108                  33-21  1.652172e+12   both
# 1123                  33-15  1.682505e+12   both
# 1124                  33-29  1.639728e+12   both
# 1212                  37-23  1.639728e+12   both
# 1213                  37-28  1.652173e+12   both
# 1217                  37-23  1.639730e+12   both
# 1218                  37-28  1.696896e+12   both
# 1423                 38-105  1.639728e+12   both
# 1424                   38-3  1.646403e+12   both
# 1504                  38-78  1.675260e+12   both
# 1505                  38-82  1.639728e+12   both

# %%
vbo_transboundary.shape
# Out:
# (1673, 89)

# %%
extra_matches.shape
# Out:
# (1695, 10)

# %%
all_matches = simple_matches.merge(
    extra_matches[["VBO id", "dadis_transboundary_id", "dadis_species_id"]],
    how="left",
    on="VBO id",
    suffixes=(None, "_extra"),
    sort=False
).convert_dtypes()
all_matches.head()
# Out:
#         VBO id                       term label      DADIS_name  \
# 0  VBO:0000012         Dromedary Bactrian Camel            <NA>
# 1  VBO:0000038                  Alpaca (Alpaca)          Alpaca
# 2  VBO:0000039                 Huacaya (Alpaca)         Huacaya
# 3  VBO:0000040                    Suri (Alpaca)            Suri
# 4  VBO:0000041  American Bison (American Bison)  American Bison
#
#   DADIS_species_name dadis_transboundary_id  dadis_species_id     _merge  \
# 0               <NA>                   <NA>              <NA>  left_only
# 1             Alpaca                   <NA>              <NA>  left_only
# 2             Alpaca                    1-1                 1       both
# 3             Alpaca                    1-2                 1       both
# 4     American Bison                    2-1                 2       both
#
#   dadis_transboundary_id_extra  dadis_species_id_extra
# 0                         <NA>                    <NA>
# 1                         <NA>                    <NA>
# 2                          1-1                       1
# 3                          1-2                       1
# 4                         <NA>                    <NA>

# %%
all_matches.pipe(lambda df: df.loc[df["dadis_transboundary_id"].isna() & ~ df["dadis_transboundary_id_extra"].isna(), :]).head()
# Out:
#          VBO id               term label      DADIS_name DADIS_species_name  \
# 42  VBO:0000078      Nili-Ravi (Buffalo)       Nili-Ravi            Buffalo
# 53  VBO:0000090  Aberdeen-Angus (Cattle)  Aberdeen-Angus             Cattle
# 59  VBO:0000096         Ala-Tau (Cattle)         Ala-Tau             Cattle
# 67  VBO:0000104           Angus (Cattle)           Angus             Cattle
# 68  VBO:0000104           Angus (Cattle)           Angus             Cattle
#
#    dadis_transboundary_id  dadis_species_id     _merge  \
# 42                   <NA>              <NA>  left_only
# 53                   <NA>              <NA>  left_only
# 59                   <NA>              <NA>  left_only
# 67                   <NA>              <NA>  left_only
# 68                   <NA>              <NA>  left_only
#
#    dadis_transboundary_id_extra  dadis_species_id_extra
# 42                         5-11                       5
# 53                          7-2                       7
# 59                          7-7                       7
# 67                          7-2                       7
# 68                          7-7                       7

# %%
simple_ids = all_matches["dadis_transboundary_id"]
extra_ids = all_matches["dadis_transboundary_id_extra"]
all_matches["dadis_transboundary_id"] = simple_ids.where(~ simple_ids.isna(), extra_ids)

# %%
all_matches["dadis_transboundary_id"].isna().value_counts()
# Out:
# dadis_transboundary_id
# False    1076
# True      619
# Name: count, dtype: int64

# %%
all_matches.head()
# Out:
#         VBO id                       term label      DADIS_name  \
# 0  VBO:0000012         Dromedary Bactrian Camel            <NA>
# 1  VBO:0000038                  Alpaca (Alpaca)          Alpaca
# 2  VBO:0000039                 Huacaya (Alpaca)         Huacaya
# 3  VBO:0000040                    Suri (Alpaca)            Suri
# 4  VBO:0000041  American Bison (American Bison)  American Bison
#
#   DADIS_species_name dadis_transboundary_id  dadis_species_id     _merge  \
# 0               <NA>                   <NA>              <NA>  left_only
# 1             Alpaca                   <NA>              <NA>  left_only
# 2             Alpaca                    1-1                 1       both
# 3             Alpaca                    1-2                 1       both
# 4     American Bison                    2-1                 2       both
#
#   dadis_transboundary_id_extra  dadis_species_id_extra
# 0                         <NA>                    <NA>
# 1                         <NA>                    <NA>
# 2                          1-1                       1
# 3                          1-2                       1
# 4                         <NA>                    <NA>

# %%
vbo_matched = vbo_transboundary.merge(
    all_matches[["VBO id", "dadis_transboundary_id"]],
    on="VBO id",
    how="left",
    sort=False
)
vbo_matched.head()
# Out:
#         VBO id                       term label  \
# 0  VBO:0000012         Dromedary Bactrian Camel
# 1  VBO:0000038                  Alpaca (Alpaca)
# 2  VBO:0000039                 Huacaya (Alpaca)
# 3  VBO:0000040                    Suri (Alpaca)
# 4  VBO:0000041  American Bison (American Bison)
#
#   breed name to be used for label species to be used for label  \
# 0                            <NA>                         <NA>
# 1                          Alpaca                       Alpaca
# 2                         Huacaya                       Alpaca
# 3                            Suri                       Alpaca
# 4                  American Bison               American Bison
#
#   internal term merge indicator vboid into vboid  \
# 0                                           <NA>
# 1                                           <NA>
# 2                                           <NA>
# 3                                           <NA>
# 4                                           <NA>
#
#   internal date and issue separated by pipe YYMMDD-issue  \
# 0                                               <NA>
# 1                                               <NA>
# 2                                               <NA>
# 3                                               <NA>
# 4                                               <NA>
#
#   GH issue NOT merge obsolete        parent ID          source for parents  \
# 0                        <NA>   NCBITaxon:9836                        <NA>
# 1                        <NA>  NCBITaxon:30538  https://www.fao.org/dad-is
# 2                        <NA>  NCBITaxon:30538  https://www.fao.org/dad-is
# 3                        <NA>  NCBITaxon:30538  https://www.fao.org/dad-is
# 4                        <NA>   NCBITaxon:9901  https://www.fao.org/dad-is
#
#                                 source for parents.1  ...  replacement label  \
# 0  DOI:10.1016/j.jasrep.2021.103038|PMID:31969478...  ...               <NA>
# 1                                               <NA>  ...               <NA>
# 2                                               <NA>  ...               <NA>
# 3                                               <NA>  ...               <NA>
# 4                                               <NA>  ...               <NA>
#
#    comment.1  GH issue obsolescence reason curator note      DADIS_name  \
# 0       <NA>      <NA>                <NA>         <NA>            <NA>
# 1       <NA>      <NA>                <NA>         <NA>          Alpaca
# 2       <NA>      <NA>                <NA>         <NA>         Huacaya
# 3       <NA>      <NA>                <NA>         <NA>            Suri
# 4       <NA>      <NA>                <NA>         <NA>  American Bison
#
#    DADIS_species_name DADIS_country DADIS_ISO3_code  dadis_transboundary_id
# 0                <NA>          <NA>            <NA>                    <NA>
# 1              Alpaca          <NA>            <NA>                    <NA>
# 2              Alpaca          <NA>            <NA>                     1-1
# 3              Alpaca          <NA>            <NA>                     1-2
# 4      American Bison          <NA>            <NA>                     2-1
#
# [5 rows x 90 columns]
