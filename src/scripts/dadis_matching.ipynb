# %%
import csv
import json
import os
from typing import IO, TextIO

import pandas as pd

from dadis_client.client import DadisClient

# %%
API_KEY = os.environ["DADIS_API_KEY"]

# %%
client = DadisClient(api_key=API_KEY, prod=True)

# %%
def full_matching_workflow(
    input_filename: str,
    output_filename: str,
    dadis_api_key: str) -> pd.DataFrame:
    """
    Perform the full matching workflow:

    - Read VBO data from input_filename
    - Match to DADIS to get dadis_transboundary_id
    - Save to a new TSV file at output_filename
    """
    client = DadisClient(api_key=dadis_api_key)
    vbo_data = read_vbo_data(input_filename)
    matched_breeds = match_vbo_breeds(vbo_data=vbo_data, client=client)

    print(f"Writing output file to {output_filename}:")
    output_file = create_output_tsv(input_filename=input_filename, output_filename=output_filename, extra_cols=["dadis_transboundary_id"])
    matched_breeds.to_csv(output_file, sep="\t", index=False, header=False)
    output_file.close()
    print("Output written.")
    return matched_breeds
    

def read_vbo_data(filename: str) -> pd.DataFrame:
    df = pd.read_table(filename, skiprows=[1]).convert_dtypes()
    return df


def get_dadis_species(client: DadisClient) -> pd.DataFrame:
    resp = client.get_all_species()
    all_species = []
    for s in resp.response:
        species = {"dadis_species_id": s.id, "dadis_species_name": s.name["en"]}
        all_species.append(species)
    return pd.DataFrame.from_records(all_species)


def get_canonical_dadis_transboundary(client: DadisClient) -> pd.DataFrame:
    """
    DADIS has a canonical name for each transboundary breed, fetch these
    and return them as a dataframe
    """
    resp = client.get_all_transboundary_names()
    df = (
        pd.DataFrame.from_records([b.model_dump() for b in resp.response])
        .rename(columns={"speciesId": "dadis_species_id"})
    )
    species_df = get_dadis_species(client)
    df = df.merge(species_df, how="left", on="dadis_species_id")
    df = df.rename(columns={"id": "dadis_transboundary_id", "name": "dadis_breed_name"})
    return df

def get_all_dadis_transboundary(client: DadisClient) -> pd.DataFrame:
    """
    Get all names for DADIS transboundary breeds, some VBO entries
    may use non-canonical names
    """
    resp = client.get_all_transboundary_breeds()
    df = (
        pd.DataFrame.from_records([b.model_dump() for b in resp.response])
        .rename(columns={
            "speciesId": "dadis_species_id", 
            "name": "dadis_breed_name", 
            "transboundaryId": "dadis_transboundary_id",
            "id": "dadis_breed_id",
            "iso3": "dadis_iso3_code",
        })
        .drop_duplicates(subset=["dadis_species_id", "dadis_breed_name", "dadis_transboundary_id"])
    )
    species_df = get_dadis_species(client)
    result = (
        df
        .merge(species_df, how="left", on="dadis_species_id")
        .sort_values(["dadis_transboundary_id", "dadis_breed_name"])
    )
    return result


def get_simple_matches(vbo_data: pd.DataFrame, client: DadisClient) -> pd.DataFrame:
    """
    Match VBO entries to DADIS transboundary breeds based on their
    canonical names. Return a dataframe containing the matches
    """
    dadis_canonical = get_canonical_dadis_transboundary(client=client)
    match_data = vbo_data.query("to_be_ignored != 'duplicate'")[["vbo_id", "term_label", "dadis_name", "dadis_species_name"]]
    simple_matches = (
        match_data.merge(
            dadis_canonical,
            how="left",
            left_on=["dadis_name", "dadis_species_name"],
            right_on=["dadis_breed_name", "dadis_species_name"],
            sort=False,
        )
        .drop(columns=["dadis_breed_name", "dadis_species_name"])
        .convert_dtypes()
    )
    return simple_matches


def get_extra_matches(vbo_data: pd.DataFrame, client: DadisClient) -> pd.DataFrame:
    dadis_all = get_all_dadis_transboundary(client=client)
    match_data = vbo_data.query("to_be_ignored != 'duplicate'")[["vbo_id", "term_label", "dadis_name", "dadis_species_name"]]
    extra_matches = (
        match_data.merge(
            dadis_all,
            how="left",
            left_on=["dadis_name", "dadis_species_name"],
            right_on=["dadis_breed_name", "dadis_species_name"],
            indicator=True,
            # Need to ensure we use sort=False so order stays consistent with original
            sort=False,
        )
        .drop(columns=["dadis_breed_name", "dadis_species_name"])
        .convert_dtypes()
        .drop_duplicates(subset=["vbo_id", "dadis_transboundary_id"])
    )
    counts = extra_matches["vbo_id"].value_counts()
    duplicates = counts.loc[counts >=2 ].index.tolist()
    multiple_matches = extra_matches.loc[extra_matches["vbo_id"].isin(duplicates), :]
    print("The following entries matched against multiple DADIS entries - will not be updated")
    print(multiple_matches["vbo_id"])
    extra_matches = extra_matches.loc[~ extra_matches["vbo_id"].isin(duplicates), :]
    return extra_matches


def match_vbo_breeds(vbo_data: pd.DataFrame, client: DadisClient) -> pd.DataFrame:
    """
    Match VBO entries to DADIS, based on both canonical name (preferred) or
    other transboundary name.

    Return a modified copy of vbo_data, with the 'dadis_transboundary_id' added
    """
    print("Matching to canonical DADIS names")
    simple_matches = get_simple_matches(vbo_data, client)
    print("Matching to other DADIS names")
    extra_matches = get_extra_matches(vbo_data, client)
    all_matches = simple_matches.merge(
        extra_matches[["vbo_id", "dadis_transboundary_id", "dadis_species_id"]],
        how="left",
        on="vbo_id",
        suffixes=(None, "_extra"),
        sort=False
    ).convert_dtypes()
    # Fill in simple matches with extra matches, where no simple match was found
    simple_ids = all_matches["dadis_transboundary_id"]
    extra_ids = all_matches["dadis_transboundary_id_extra"]
    all_matches["dadis_transboundary_id"] = simple_ids.where(~ simple_ids.isna(), extra_ids)

    n_total = all_matches.shape[0]
    n_matched = all_matches["dadis_transboundary_id"].notna().sum()
    print(f"{n_matched} / {n_total} VBO entries matched with DADIS")
    
    return vbo_data.merge(
        all_matches[["vbo_id", "dadis_transboundary_id"]],
        on="vbo_id",
        how="left",
        sort=False
    )


def create_output_tsv(input_filename: str, output_filename: str, extra_cols: list[str] = None) -> TextIO:
    """
    Copy the 2 header lines from the input file to the output file. Return
    a file object for the output file, so pandas can write the rest of the file
    """
    file_out = open(output_filename, "w")
    csv_out = csv.writer(file_out, dialect="excel-tab")
    with open(input_filename) as file_in:
        csv_in = csv.reader(file_in, dialect="excel-tab")
        for index, line in enumerate(range(2)):
            header = next(csv_in)
            if extra_cols is not None:
                if index == 0:
                    header += extra_cols
                if index == 1:
                    header += ['' for i in range(len(extra_cols))]
            csv_out.writerow(header)
    return file_out

# %% [markdown]
# # Test full updating process

# %%
result = full_matching_workflow(input_filename="data/dadistransbound.tsv", output_filename="example_transboundary_output.tsv", dadis_api_key=API_KEY)
# Out:
# Matching to canonical DADIS names
# Matching to other DADIS names
# The following entries matched against multiple DADIS entries - will not be updated
# 19      VBO:0000056
# 20      VBO:0000056
# 67      VBO:0000104
# 68      VBO:0000104
# 144     VBO:0000184
# 145     VBO:0000184
# 168     VBO:0000207
# 169     VBO:0000207
# 177     VBO:0000215
# 178     VBO:0000215
# 227     VBO:0000265
# 228     VBO:0000265
# 235     VBO:0000272
# 236     VBO:0000272
# 279     VBO:0000315
# 280     VBO:0000315
# 286     VBO:0000321
# 287     VBO:0000321
# 355     VBO:0000389
# 356     VBO:0000389
# 389     VBO:0000422
# 390     VBO:0000422
# 414     VBO:0000446
# 415     VBO:0000446
# 614     VBO:0000645
# 615     VBO:0000645
# 677     VBO:0000717
# 678     VBO:0000717
# 711     VBO:0000751
# 712     VBO:0000751
# 911     VBO:0000951
# 912     VBO:0000951
# 1107    VBO:0001146
# 1108    VBO:0001146
# 1123    VBO:0001161
# 1124    VBO:0001161
# 1212    VBO:0001249
# 1213    VBO:0001249
# 1217    VBO:0001253
# 1218    VBO:0001253
# 1423    VBO:0001461
# 1424    VBO:0001461
# 1504    VBO:0001541
# 1505    VBO:0001541
# Name: vbo_id, dtype: string
# 1052 / 1673 VBO entries matched with DADIS
# Writing output file to example_transboundary_output.tsv:
# Output written.

# %%
result.head()
# Out:
#         vbo_id                term_label to_be_ignored  \
# 0  VBO:0000012  Dromedary Bactrian Camel          <NA>
# 1  VBO:0000038                      <NA>          <NA>
# 2  VBO:0000039          Huacaya (Alpaca)          <NA>
# 3  VBO:0000040             Suri (Alpaca)          <NA>
# 4  VBO:0000041                      <NA>          <NA>
#
#   breed_name_to_be_used_for_label species_to_be_used_for_label  \
# 0                            <NA>                         <NA>
# 1                          Alpaca                       Alpaca
# 2                         Huacaya                       Alpaca
# 3                            Suri                       Alpaca
# 4                  American Bison               American Bison
#
#   internal_term_merge_indicator_vboid_into_vboid  \
# 0                                           <NA>
# 1                                           <NA>
# 2                                           <NA>
# 3                                           <NA>
# 4                                           <NA>
#
#   internal_date_and_issue_separated_by_pipe_yymmdd_dash_issue  \
# 0                                               <NA>
# 1                              231120-126|231212-137
# 2                                         231120-126
# 3                                         231120-126
# 4                              231120-126|231212-137
#
#                          gh_issue_NOT_merge_obsolete        parent_ID  \
# 0                                               <NA>   NCBITaxon:9836
# 1  https://github.com/monarch-initiative/vertebra...  NCBITaxon:30538
# 2  https://github.com/monarch-initiative/vertebra...  NCBITaxon:30538
# 3  https://github.com/monarch-initiative/vertebra...  NCBITaxon:30538
# 4  https://github.com/monarch-initiative/vertebra...   NCBITaxon:9901
#
#            source_for_parents  ... comment.1 GH_issue  obsolescence_reason  \
# 0                        <NA>  ...      <NA>     <NA>                 <NA>
# 1  https://www.fao.org/dad-is  ...      <NA>     <NA>                 <NA>
# 2  https://www.fao.org/dad-is  ...      <NA>     <NA>                 <NA>
# 3  https://www.fao.org/dad-is  ...      <NA>     <NA>                 <NA>
# 4  https://www.fao.org/dad-is  ...      <NA>     <NA>                 <NA>
#
#   curator_note      dadis_name dadis_species_name dadis_country  \
# 0         <NA>            <NA>               <NA>          <NA>
# 1         <NA>          Alpaca             Alpaca          <NA>
# 2         <NA>         Huacaya             Alpaca          <NA>
# 3         <NA>            Suri             Alpaca          <NA>
# 4         <NA>  American Bison     American Bison          <NA>
#
#   dadis_iso3_code                           in_subset_transboundary  \
# 0            <NA>                                              <NA>
# 1            <NA>  http://purl.obolibrary.org/obo/vbo#transboundary
# 2            <NA>  http://purl.obolibrary.org/obo/vbo#transboundary
# 3            <NA>  http://purl.obolibrary.org/obo/vbo#transboundary
# 4            <NA>  http://purl.obolibrary.org/obo/vbo#transboundary
#
#   dadis_transboundary_id
# 0                   <NA>
# 1                   <NA>
# 2                    1-1
# 3                    1-2
# 4                    2-1
#
# [5 rows x 92 columns]

# %%
result.loc[result["vbo_id"] == "VBO:0000991", :]
# Out:
#           vbo_id               term_label to_be_ignored  \
# 936  VBO:0000991  Icelandic Horse (Horse)          <NA>
# 937  VBO:0000991                     <NA>     duplicate
#
#     breed_name_to_be_used_for_label species_to_be_used_for_label  \
# 936                 Icelandic Horse                        Horse
# 937                    Iceland Pony                        Horse
#
#     internal_term_merge_indicator_vboid_into_vboid  \
# 936                   VBO:0000990 into VBO:0000991
# 937                   VBO:0000990 into VBO:0000991
#
#     internal_date_and_issue_separated_by_pipe_yymmdd_dash_issue  \
# 936                               230207-75|231120-126
# 937                               230207-75|231120-126
#
#     gh_issue_NOT_merge_obsolete       parent_ID          source_for_parents  \
# 936                        <NA>  NCBITaxon:9796  https://www.fao.org/dad-is
# 937                        <NA>            <NA>                        <NA>
#
#      ... comment.1                                           GH_issue  \
# 936  ...      <NA>                                               <NA>
# 937  ...      <NA>  https://github.com/monarch-initiative/vertebra...
#
#      obsolescence_reason curator_note       dadis_name dadis_species_name  \
# 936                 <NA>         <NA>  Icelandic Horse              Horse
# 937                 <NA>         <NA>     Iceland Pony              Horse
#
#     dadis_country dadis_iso3_code  \
# 936          <NA>            <NA>
# 937          <NA>            <NA>
#
#                               in_subset_transboundary dadis_transboundary_id
# 936  http://purl.obolibrary.org/obo/vbo#transboundary                  24-73
# 937  http://purl.obolibrary.org/obo/vbo#transboundary                  24-73
#
# [2 rows x 92 columns]

# %% [markdown]
# # Step-by-step process: for debugging
#
# Note: may not be fully up to date with the process above.

# %%
dadis_species = get_dadis_species(client)
dadis_species.head()
# Out:
#    dadis_species_id dadis_species_name
# 0                 1             Alpaca
# 1                 2     American Bison
# 2                 3                Ass
# 3                 4     Bactrian camel
# 4                 5            Buffalo

# %%
dadis_canonical = get_canonical_dadis_transboundary(client=client)
dadis_canonical.head()
# Out:
#   dadis_transboundary_id  dadis_species_id dadis_breed_name dadis_species_name
# 0                    1-1                 1          Huacaya             Alpaca
# 1                    1-2                 1             Suri             Alpaca
# 2                    2-1                 2   American Bison     American Bison
# 3                    3-1                 3      Asino Sardo                Ass
# 4                    3-2                 3    Balkan Donkey                Ass

# %%
dadis_all = get_all_dadis_transboundary(client=client)
dadis_all.head()
# Out:
#                             dadis_breed_id dadis_breed_name dadis_iso3_code  \
# 147   da0f5e4b-2dc4-4119-bb9a-6d87d88b2a3c          Huacaya             AUS
# 148   32354ff8-1f74-4e90-abb5-657753427508             Suri             AUS
# 617   56378f94-0804-411b-a7bd-a9b0a43bf187             Sury             BOL
# 1091  ba06f2a8-caca-4dce-8c22-8599b349b85e             Test             DEU
# 242   0c273dfe-f832-431b-938a-b9235a6dbffc           Chital             AUS
#
#       dadis_species_id dadis_transboundary_id      updatedAt  \
# 147                  1                    1-1  1652172491000
# 148                  1                    1-2  1652172491000
# 617                  1                    1-2  1665583332000
# 1091                 1                    1-2  1678781404000
# 242                 11                   11-1  1652172493000
#
#      dadis_species_name
# 147              Alpaca
# 148              Alpaca
# 617              Alpaca
# 1091             Alpaca
# 242                Deer

# %%
dadis_all.dtypes
# Out:
# dadis_breed_id            object
# dadis_breed_name          object
# dadis_iso3_code           object
# dadis_species_id           int64
# dadis_transboundary_id    object
# updatedAt                  int64
# dadis_species_name        object
# dtype: object

# %% [markdown]
# ## VBO transboundary data

# %%
VBO_TRANSBOUNDARY_FILENAME = "data/dadistransbound.tsv"

# %%
vbo_transboundary = pd.read_table(VBO_TRANSBOUNDARY_FILENAME, skiprows=[1]).convert_dtypes()
# Drop problematic entry: VBO:0000991 - Icelandic Horse/Iceland Pony
#dup_entry = (vbo_transboundary["VBO id"] == "VBO:0000991") & (vbo_transboundary["term label"].isna())
#vbo_transboundary = vbo_transboundary.loc[~ dup_entry, :]
vbo_transboundary.head()
# Out:
#         vbo_id                term_label to_be_ignored  \
# 0  VBO:0000012  Dromedary Bactrian Camel          <NA>
# 1  VBO:0000038                      <NA>          <NA>
# 2  VBO:0000039          Huacaya (Alpaca)          <NA>
# 3  VBO:0000040             Suri (Alpaca)          <NA>
# 4  VBO:0000041                      <NA>          <NA>
#
#   breed_name_to_be_used_for_label species_to_be_used_for_label  \
# 0                            <NA>                         <NA>
# 1                          Alpaca                       Alpaca
# 2                         Huacaya                       Alpaca
# 3                            Suri                       Alpaca
# 4                  American Bison               American Bison
#
#   internal_term_merge_indicator_vboid_into_vboid  \
# 0                                           <NA>
# 1                                           <NA>
# 2                                           <NA>
# 3                                           <NA>
# 4                                           <NA>
#
#   internal_date_and_issue_separated_by_pipe_yymmdd_dash_issue  \
# 0                                               <NA>
# 1                              231120-126|231212-137
# 2                                         231120-126
# 3                                         231120-126
# 4                              231120-126|231212-137
#
#                          gh_issue_NOT_merge_obsolete        parent_ID  \
# 0                                               <NA>   NCBITaxon:9836
# 1  https://github.com/monarch-initiative/vertebra...  NCBITaxon:30538
# 2  https://github.com/monarch-initiative/vertebra...  NCBITaxon:30538
# 3  https://github.com/monarch-initiative/vertebra...  NCBITaxon:30538
# 4  https://github.com/monarch-initiative/vertebra...   NCBITaxon:9901
#
#            source_for_parents  ... replacement_label comment.1  GH_issue  \
# 0                        <NA>  ...              <NA>      <NA>      <NA>
# 1  https://www.fao.org/dad-is  ...              <NA>      <NA>      <NA>
# 2  https://www.fao.org/dad-is  ...              <NA>      <NA>      <NA>
# 3  https://www.fao.org/dad-is  ...              <NA>      <NA>      <NA>
# 4  https://www.fao.org/dad-is  ...              <NA>      <NA>      <NA>
#
#   obsolescence_reason curator_note      dadis_name dadis_species_name  \
# 0                <NA>         <NA>            <NA>               <NA>
# 1                <NA>         <NA>          Alpaca             Alpaca
# 2                <NA>         <NA>         Huacaya             Alpaca
# 3                <NA>         <NA>            Suri             Alpaca
# 4                <NA>         <NA>  American Bison     American Bison
#
#   dadis_country dadis_iso3_code  \
# 0          <NA>            <NA>
# 1          <NA>            <NA>
# 2          <NA>            <NA>
# 3          <NA>            <NA>
# 4          <NA>            <NA>
#
#                             in_subset_transboundary
# 0                                              <NA>
# 1  http://purl.obolibrary.org/obo/vbo#transboundary
# 2  http://purl.obolibrary.org/obo/vbo#transboundary
# 3  http://purl.obolibrary.org/obo/vbo#transboundary
# 4  http://purl.obolibrary.org/obo/vbo#transboundary
#
# [5 rows x 91 columns]

# %%
vbo_transboundary.columns
# Out:
# Index(['vbo_id', 'term_label', 'to_be_ignored',
#        'breed_name_to_be_used_for_label', 'species_to_be_used_for_label',
#        'internal_term_merge_indicator_vboid_into_vboid',
#        'internal_date_and_issue_separated_by_pipe_yymmdd_dash_issue',
#        'gh_issue_NOT_merge_obsolete', 'parent_ID', 'source_for_parents',
#        'source_for_parents.1', 'parent_ID.1', 'source_for_parents.2',
#        'source_for_parents.3', 'most_common_name',
#        'synonym_type_most_common_name', 'source_for_most_common_name',
#        'source_for_most_common_name.1', 'synonym_dadis_name_not_used_in_label',
#        'source_for_synonym_dadis', 'source_for_synonym_dadis.1', 'synonym_1',
#        'source_for_synonym_1', 'source_for_synonym_1.1', 'synonym_2',
#        'source_for_synonym_2', 'source_for_synonym_2.1', 'synonym_3',
#        'source_for_synonym_3', 'source_for_synonym_3.1', 'synonym_4',
#        'source_for_synonym_4', 'source_for_synonym_4.1', 'synonym_5',
#        'source_for_synonym_5', 'source_for_synonym_5.1',
#        'synonym_label_from_merged_term', 'source_for_merged_term',
#        'Breed_code_1', 'all_source_for_breed_code_1_separated_by_pipe',
#        'all_source_for_breed_code_1_separated_by_pipe.1', 'Breed_code_2',
#        'all_source_for_breed_code_2_separated_by_pipe',
#        'all_source_for_breed_code_2_separated_by_pipe.1', 'definition ',
#        'definition_xref', 'definition_xref.1', 'xref1', 'source_for_xref1',
#        'source_for_xref1.1', 'xref2', 'source_for_xref2', 'source_for_xref2.1',
#        'omia_xref_internal', 'recognition_status_1',
#        'source_for_recognition_status_1', 'source_for_recognition_status_1.1',
#        'recognition_status_2', 'source_for_recognition_status_2',
#        'source_for_recognition_status_2.1', 'recognition_status_3',
#        'source_for_recognition_status_3', 'source_for_recognition_status_3.1',
#        'source_for_breed', 'source_for_breed.1', 'contributors',
#        'contributors.1', 'comment', 'general_comment',
#        'comment_from_obsoletion', 'description_of_origin',
#        'source_for_description_of_origin',
#        'source_for_description_of_origin.1', 'domestication_status',
#        'source_for_domestication_status',
#        'wikidata_link_for_the_country_exists_in_country_subclass',
#        'source_for_country_subclass', 'source_for_country_subclass.1',
#        'obsoletion_type', 'obsolete', 'replacement_term', 'replacement_label',
#        'comment.1', 'GH_issue', 'obsolescence_reason', 'curator_note',
#        'dadis_name', 'dadis_species_name', 'dadis_country', 'dadis_iso3_code',
#        'in_subset_transboundary'],
#       dtype='object')

# %%
vbo_transboundary.loc[vbo_transboundary["vbo_id"] == "VBO:0000991", :]
# Out:
#           vbo_id               term_label to_be_ignored  \
# 936  VBO:0000991  Icelandic Horse (Horse)          <NA>
# 937  VBO:0000991                     <NA>     duplicate
#
#     breed_name_to_be_used_for_label species_to_be_used_for_label  \
# 936                 Icelandic Horse                        Horse
# 937                    Iceland Pony                        Horse
#
#     internal_term_merge_indicator_vboid_into_vboid  \
# 936                   VBO:0000990 into VBO:0000991
# 937                   VBO:0000990 into VBO:0000991
#
#     internal_date_and_issue_separated_by_pipe_yymmdd_dash_issue  \
# 936                               230207-75|231120-126
# 937                               230207-75|231120-126
#
#     gh_issue_NOT_merge_obsolete       parent_ID          source_for_parents  \
# 936                        <NA>  NCBITaxon:9796  https://www.fao.org/dad-is
# 937                        <NA>            <NA>                        <NA>
#
#      ... replacement_label comment.1  \
# 936  ...              <NA>      <NA>
# 937  ...              <NA>      <NA>
#
#                                               GH_issue obsolescence_reason  \
# 936                                               <NA>                <NA>
# 937  https://github.com/monarch-initiative/vertebra...                <NA>
#
#     curator_note       dadis_name dadis_species_name dadis_country  \
# 936         <NA>  Icelandic Horse              Horse          <NA>
# 937         <NA>     Iceland Pony              Horse          <NA>
#
#     dadis_iso3_code                           in_subset_transboundary
# 936            <NA>  http://purl.obolibrary.org/obo/vbo#transboundary
# 937            <NA>  http://purl.obolibrary.org/obo/vbo#transboundary
#
# [2 rows x 91 columns]

# %%
vbo_transboundary.shape
# Out:
# (1674, 91)

# %%
def get_simple_matches(vbo_data: pd.DataFrame, client: DadisClient) -> pd.DataFrame:
    """
    Match VBO entries to DADIS transboundary breeds based on their
    canonical names. Return a dataframe containing the matches
    """
    dadis_canonical = get_canonical_dadis_transboundary(client=client)
    match_data = vbo_data.query("to_be_ignored != 'duplicate'")[["vbo_id", "term_label", "dadis_name", "dadis_species_name"]]
    simple_matches = (
        match_data.merge(
            dadis_canonical,
            how="left",
            left_on=["dadis_name", "dadis_species_name"],
            right_on=["dadis_breed_name", "dadis_species_name"],
            sort=False,
        )
        .drop(columns=["dadis_breed_name", "dadis_species_name"])
        .convert_dtypes()
    )
    return simple_matches


def get_extra_matches(vbo_data: pd.DataFrame, client: DadisClient) -> pd.DataFrame:
    dadis_all = get_all_dadis_transboundary(client=client)
    match_data = vbo_data.query("to_be_ignored != 'duplicate'")[["vbo_id", "term_label", "dadis_name", "dadis_species_name"]]
    extra_matches = (
        match_data.merge(
            dadis_all,
            how="left",
            left_on=["dadis_name", "dadis_species_name"],
            right_on=["dadis_breed_name", "dadis_species_name"],
            indicator=True,
            # Need to ensure we use sort=False so order stays consistent with original
            sort=False,
        )
        .drop(columns=["dadis_breed_name", "dadis_species_name"])
        .convert_dtypes()
        .drop_duplicates(subset=["vbo_id", "dadis_transboundary_id"])
    )
    counts = extra_matches["vbo_id"].value_counts()
    duplicates = counts.loc[counts >=2 ].index.tolist()
    multiple_matches = extra_matches.loc[extra_matches["vbo_id"].isin(duplicates), :]
    print("The following entries matched against multiple DADIS entries - will not be updated")
    print(multiple_matches["vbo_id"])
    extra_matches = extra_matches.loc[~ extra_matches["vbo_id"].isin(duplicates), :]
    return extra_matches


def match_vbo_breeds(vbo_data: pd.DataFrame, client: DadisClient) -> pd.DataFrame:
    """
    Match VBO entries to DADIS, based on both canonical name (preferred) or
    other transboundary name.

    Return a modified copy of vbo_data, with the 'dadis_transboundary_id' added
    """
    print("Matching to canonical DADIS names")
    simple_matches = get_simple_matches(vbo_data, client)
    print("Matching to other DADIS names")
    extra_matches = get_extra_matches(vbo_data, client)
    all_matches = simple_matches.merge(
        extra_matches[["vbo_id", "dadis_transboundary_id", "dadis_species_id"]],
        how="left",
        on="vbo_id",
        suffixes=(None, "_extra"),
        sort=False
    ).convert_dtypes()
    # Fill in simple matches with extra matches, where no simple match was found
    simple_ids = all_matches["dadis_transboundary_id"]
    extra_ids = all_matches["dadis_transboundary_id_extra"]
    all_matches["dadis_transboundary_id"] = simple_ids.where(~ simple_ids.isna(), extra_ids)

    n_total = all_matches.shape[0]
    n_matched = all_matches["dadis_transboundary_id"].notna().sum()
    print(f"{n_matched} / {n_total} VBO entries matched with DADIS")
    
    return vbo_data.merge(
        all_matches[["vbo_id", "dadis_transboundary_id"]],
        on="vbo_id",
        how="left",
        sort=False
    )

# %%
simple_matches = get_simple_matches(vbo_data=vbo_transboundary, client=client)
simple_matches.head()
# Out:
#         vbo_id                term_label      dadis_name  \
# 0  VBO:0000012  Dromedary Bactrian Camel            <NA>
# 1  VBO:0000038                      <NA>          Alpaca
# 2  VBO:0000039          Huacaya (Alpaca)         Huacaya
# 3  VBO:0000040             Suri (Alpaca)            Suri
# 4  VBO:0000041                      <NA>  American Bison
#
#   dadis_transboundary_id  dadis_species_id
# 0                   <NA>              <NA>
# 1                   <NA>              <NA>
# 2                    1-1                 1
# 3                    1-2                 1
# 4                    2-1                 2

# %%
simple_matches.loc[simple_matches["vbo_id"] == "VBO:0000991", :]
# Out:
#           vbo_id               term_label       dadis_name  \
# 936  VBO:0000991  Icelandic Horse (Horse)  Icelandic Horse
#
#     dadis_transboundary_id  dadis_species_id
# 936                  24-73                24

# %%
extra_matches = get_extra_matches(vbo_data=vbo_transboundary, client=client)
extra_matches.head()
# Out:
# The following entries matched against multiple DADIS entries - will not be updated
# 19      VBO:0000056
# 20      VBO:0000056
# 67      VBO:0000104
# 68      VBO:0000104
# 144     VBO:0000184
# 145     VBO:0000184
# 168     VBO:0000207
# 169     VBO:0000207
# 177     VBO:0000215
# 178     VBO:0000215
# 227     VBO:0000265
# 228     VBO:0000265
# 235     VBO:0000272
# 236     VBO:0000272
# 279     VBO:0000315
# 280     VBO:0000315
# 286     VBO:0000321
# 287     VBO:0000321
# 355     VBO:0000389
# 356     VBO:0000389
# 389     VBO:0000422
# 390     VBO:0000422
# 414     VBO:0000446
# 415     VBO:0000446
# 614     VBO:0000645
# 615     VBO:0000645
# 677     VBO:0000717
# 678     VBO:0000717
# 711     VBO:0000751
# 712     VBO:0000751
# 911     VBO:0000951
# 912     VBO:0000951
# 1107    VBO:0001146
# 1108    VBO:0001146
# 1123    VBO:0001161
# 1124    VBO:0001161
# 1212    VBO:0001249
# 1213    VBO:0001249
# 1217    VBO:0001253
# 1218    VBO:0001253
# 1423    VBO:0001461
# 1424    VBO:0001461
# 1504    VBO:0001541
# 1505    VBO:0001541
# Name: vbo_id, dtype: string
#         vbo_id                term_label      dadis_name  \
# 0  VBO:0000012  Dromedary Bactrian Camel            <NA>
# 1  VBO:0000038                      <NA>          Alpaca
# 2  VBO:0000039          Huacaya (Alpaca)         Huacaya
# 3  VBO:0000040             Suri (Alpaca)            Suri
# 4  VBO:0000041                      <NA>  American Bison
#
#                          dadis_breed_id dadis_iso3_code  dadis_species_id  \
# 0                                  <NA>            <NA>              <NA>
# 1                                  <NA>            <NA>              <NA>
# 2  da0f5e4b-2dc4-4119-bb9a-6d87d88b2a3c             AUS                 1
# 3  32354ff8-1f74-4e90-abb5-657753427508             AUS                 1
# 4                                  <NA>            <NA>              <NA>
#
#   dadis_transboundary_id      updatedAt     _merge
# 0                   <NA>           <NA>  left_only
# 1                   <NA>           <NA>  left_only
# 2                    1-1  1652172491000       both
# 3                    1-2  1652172491000       both
# 4                   <NA>           <NA>  left_only

# %%
extra_matches.loc[extra_matches["vbo_id"] == "VBO:0000991", :]
# Out:
#           vbo_id               term_label       dadis_name dadis_breed_id  \
# 952  VBO:0000991  Icelandic Horse (Horse)  Icelandic Horse           <NA>
#
#     dadis_iso3_code  dadis_species_id dadis_transboundary_id  updatedAt  \
# 952            <NA>              <NA>                   <NA>       <NA>
#
#         _merge
# 952  left_only

# %%
all_matches = simple_matches.merge(
        extra_matches[["vbo_id", "dadis_transboundary_id", "dadis_species_id"]],
        how="left",
        on="vbo_id",
        suffixes=(None, "_extra"),
        sort=False
    ).convert_dtypes()
# Fill in simple matches with extra matches, where no simple match was found
simple_ids = all_matches["dadis_transboundary_id"]
extra_ids = all_matches["dadis_transboundary_id_extra"]
all_matches["dadis_transboundary_id"] = simple_ids.where(~ simple_ids.isna(), extra_ids)

# %%
all_matches.loc[all_matches["vbo_id"] == "VBO:0000991", :]
# Out:
#           vbo_id               term_label       dadis_name  \
# 936  VBO:0000991  Icelandic Horse (Horse)  Icelandic Horse
#
#     dadis_transboundary_id  dadis_species_id dadis_transboundary_id_extra  \
# 936                  24-73                24                         <NA>
#
#      dadis_species_id_extra
# 936                    <NA>

# %%
vbo_matched = match_vbo_breeds(vbo_data=vbo_transboundary, client=client)
print(vbo_matched.shape)
vbo_matched.head()
# Out:
# Matching to canonical DADIS names
# Matching to other DADIS names
# The following entries matched against multiple DADIS entries - will not be updated
# 19      VBO:0000056
# 20      VBO:0000056
# 67      VBO:0000104
# 68      VBO:0000104
# 144     VBO:0000184
# 145     VBO:0000184
# 168     VBO:0000207
# 169     VBO:0000207
# 177     VBO:0000215
# 178     VBO:0000215
# 227     VBO:0000265
# 228     VBO:0000265
# 235     VBO:0000272
# 236     VBO:0000272
# 279     VBO:0000315
# 280     VBO:0000315
# 286     VBO:0000321
# 287     VBO:0000321
# 355     VBO:0000389
# 356     VBO:0000389
# 389     VBO:0000422
# 390     VBO:0000422
# 414     VBO:0000446
# 415     VBO:0000446
# 614     VBO:0000645
# 615     VBO:0000645
# 677     VBO:0000717
# 678     VBO:0000717
# 711     VBO:0000751
# 712     VBO:0000751
# 911     VBO:0000951
# 912     VBO:0000951
# 1107    VBO:0001146
# 1108    VBO:0001146
# 1123    VBO:0001161
# 1124    VBO:0001161
# 1212    VBO:0001249
# 1213    VBO:0001249
# 1217    VBO:0001253
# 1218    VBO:0001253
# 1423    VBO:0001461
# 1424    VBO:0001461
# 1504    VBO:0001541
# 1505    VBO:0001541
# Name: vbo_id, dtype: string
# 1052 / 1673 VBO entries matched with DADIS
# (1674, 92)
#         vbo_id                term_label to_be_ignored  \
# 0  VBO:0000012  Dromedary Bactrian Camel          <NA>
# 1  VBO:0000038                      <NA>          <NA>
# 2  VBO:0000039          Huacaya (Alpaca)          <NA>
# 3  VBO:0000040             Suri (Alpaca)          <NA>
# 4  VBO:0000041                      <NA>          <NA>
#
#   breed_name_to_be_used_for_label species_to_be_used_for_label  \
# 0                            <NA>                         <NA>
# 1                          Alpaca                       Alpaca
# 2                         Huacaya                       Alpaca
# 3                            Suri                       Alpaca
# 4                  American Bison               American Bison
#
#   internal_term_merge_indicator_vboid_into_vboid  \
# 0                                           <NA>
# 1                                           <NA>
# 2                                           <NA>
# 3                                           <NA>
# 4                                           <NA>
#
#   internal_date_and_issue_separated_by_pipe_yymmdd_dash_issue  \
# 0                                               <NA>
# 1                              231120-126|231212-137
# 2                                         231120-126
# 3                                         231120-126
# 4                              231120-126|231212-137
#
#                          gh_issue_NOT_merge_obsolete        parent_ID  \
# 0                                               <NA>   NCBITaxon:9836
# 1  https://github.com/monarch-initiative/vertebra...  NCBITaxon:30538
# 2  https://github.com/monarch-initiative/vertebra...  NCBITaxon:30538
# 3  https://github.com/monarch-initiative/vertebra...  NCBITaxon:30538
# 4  https://github.com/monarch-initiative/vertebra...   NCBITaxon:9901
#
#            source_for_parents  ... comment.1 GH_issue  obsolescence_reason  \
# 0                        <NA>  ...      <NA>     <NA>                 <NA>
# 1  https://www.fao.org/dad-is  ...      <NA>     <NA>                 <NA>
# 2  https://www.fao.org/dad-is  ...      <NA>     <NA>                 <NA>
# 3  https://www.fao.org/dad-is  ...      <NA>     <NA>                 <NA>
# 4  https://www.fao.org/dad-is  ...      <NA>     <NA>                 <NA>
#
#   curator_note      dadis_name dadis_species_name dadis_country  \
# 0         <NA>            <NA>               <NA>          <NA>
# 1         <NA>          Alpaca             Alpaca          <NA>
# 2         <NA>         Huacaya             Alpaca          <NA>
# 3         <NA>            Suri             Alpaca          <NA>
# 4         <NA>  American Bison     American Bison          <NA>
#
#   dadis_iso3_code                           in_subset_transboundary  \
# 0            <NA>                                              <NA>
# 1            <NA>  http://purl.obolibrary.org/obo/vbo#transboundary
# 2            <NA>  http://purl.obolibrary.org/obo/vbo#transboundary
# 3            <NA>  http://purl.obolibrary.org/obo/vbo#transboundary
# 4            <NA>  http://purl.obolibrary.org/obo/vbo#transboundary
#
#   dadis_transboundary_id
# 0                   <NA>
# 1                   <NA>
# 2                    1-1
# 3                    1-2
# 4                    2-1
#
# [5 rows x 92 columns]

# %%
vbo_matched["vbo_id"].value_counts()
# Out:
# vbo_id
# VBO:0000991    2
# VBO:0000142    1
# VBO:0000040    1
# VBO:0000041    1
# VBO:0000042    1
#               ..
# VBO:0016849    1
# VBO:0016850    1
# VBO:0016851    1
# VBO:0016852    1
# VBO:0016853    1
# Name: count, Length: 1673, dtype: Int64

# %%
vbo_matched.loc[vbo_matched["vbo_id"] == "VBO:0000991", :]
# Out:
#           vbo_id               term_label to_be_ignored  \
# 936  VBO:0000991  Icelandic Horse (Horse)          <NA>
# 937  VBO:0000991                     <NA>     duplicate
#
#     breed_name_to_be_used_for_label species_to_be_used_for_label  \
# 936                 Icelandic Horse                        Horse
# 937                    Iceland Pony                        Horse
#
#     internal_term_merge_indicator_vboid_into_vboid  \
# 936                   VBO:0000990 into VBO:0000991
# 937                   VBO:0000990 into VBO:0000991
#
#     internal_date_and_issue_separated_by_pipe_yymmdd_dash_issue  \
# 936                               230207-75|231120-126
# 937                               230207-75|231120-126
#
#     gh_issue_NOT_merge_obsolete       parent_ID          source_for_parents  \
# 936                        <NA>  NCBITaxon:9796  https://www.fao.org/dad-is
# 937                        <NA>            <NA>                        <NA>
#
#      ... comment.1                                           GH_issue  \
# 936  ...      <NA>                                               <NA>
# 937  ...      <NA>  https://github.com/monarch-initiative/vertebra...
#
#      obsolescence_reason curator_note       dadis_name dadis_species_name  \
# 936                 <NA>         <NA>  Icelandic Horse              Horse
# 937                 <NA>         <NA>     Iceland Pony              Horse
#
#     dadis_country dadis_iso3_code  \
# 936          <NA>            <NA>
# 937          <NA>            <NA>
#
#                               in_subset_transboundary dadis_transboundary_id
# 936  http://purl.obolibrary.org/obo/vbo#transboundary                  24-73
# 937  http://purl.obolibrary.org/obo/vbo#transboundary                  24-73
#
# [2 rows x 92 columns]

# %% [markdown]
# ### Test TSV output with double header

# %%
# Create file with just the 2 header lines
output_tsv = create_output_tsv(input_filename=VBO_TRANSBOUNDARY_FILENAME, output_filename="output_test.tsv", extra_cols=["dadis_transboundary_id"])
# Write the DF from pandas, not including the header
vbo_transboundary.to_csv(output_tsv, sep="\t", index=False, header=False)
